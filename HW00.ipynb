# %% [markdown]
# <a href="https://colab.research.google.com/github/wldnjs05/26-2-DIP-JIWONLEE/blob/main/HW00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
I = plt.imread('IMG_0921.jpg')
print(I.dtype, I.shape)
plt.imshow(I)
plt.title('A wonderful place to refresh')
plt.show()
# Out:
# uint8 (3000, 4000, 3)

# %% [markdown]
# - Image file의 metadata를 확인하기

# %%
from PIL import Image
from PIL.ExifTags import TAGS

# %%
I = Image.open('IMG_0921.jpg')
exifdata = I.getexif()
for tag_id in exifdata:
    tag = TAGS.get(tag_id, tag_id)
    data = exifdata.get(tag_id)
    print(f"{tag:25}: {data}")
# Out:
# ImageWidth               : 4000
# ImageLength              : 3000
# ResolutionUnit           : 2
# ExifOffset               : 228
# Make                     : samsung
# Model                    : Galaxy S23
# Software                 : S911NKSS6DYG8
# Orientation              : 6
# DateTime                 : 2026:02:12 15:36:26
# YCbCrPositioning         : 1
# XResolution              : 72.0
# YResolution              : 72.0
